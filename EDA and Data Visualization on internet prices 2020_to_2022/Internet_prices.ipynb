# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Dataset LinK: https://www.kaggle.com/datasets/ramjasmaurya/1-gb-internet-price

# %% [markdown]
# Reading the dataset in a variable 'data'

# %%
data=pd.read_csv('worldwide internet prices in 2022 - IN 2022.csv')

# %%
# shows first 5 rows
data.head()
# Out:
#   Country code        Name  Continental region  NO. OF Internet Plans   \
# 0           IL      Israel           NEAR EAST                    27.0
# 1           KG  Kyrgyzstan   CIS (FORMER USSR)                    20.0
# 2           FJ        Fiji             OCEANIA                    18.0
# 3           IT       Italy      WESTERN EUROPE                    29.0
# 4           SD       Sudan  SUB-SAHARAN AFRICA                    33.0
#
#   Average price of 1GB (USD) Cheapest 1GB for 30 days (USD)  \
# 0                      $0.05                          $0.02
# 1                      $0.15                          $0.10
# 2                      $0.19                          $0.05
# 3                      $0.27                          $0.09
# 4                      $0.27                          $0.03
#
#   Most expensive 1GB (USD) Average price of 1GB (USD  at the start of 2021)  \
# 0                   $20.95                                            $0.11
# 1                    $7.08                                            $0.21
# 2                    $0.85                                            $0.59
# 3                    $3.54                                            $0.43
# 4                    $0.92                                            $0.63
#
#   Average price of 1GB (USD – at start of 2020)
# 0                                         $0.90
# 1                                         $0.27
# 2                                         $3.57
# 3                                         $1.73
# 4                                         $0.68

# %%
# shows last 5 rows
data.tail()
# Out:
#     Country code                            Name  Continental region  \
# 237           VA         Vatican City (Holy See)              Europe
# 238           VE                       Venezuela       SOUTH AMERICA
# 239           WF               Wallis and Futuna             OCEANIA
# 240           CD  Congo (Democratic Republic of)  SUB-SAHARAN AFRICA
# 241           ZW                        Zimbabwe  SUB-SAHARAN AFRICA
#
#      NO. OF Internet Plans                 Average price of 1GB (USD)  \
# 237                     NaN                              NO PROVIDERS
# 238                     NaN                            HYPERINFLATION
# 239                     NaN                              NO PROVIDERS
# 240                     NaN  Prices listed in non-convertible 'units'
# 241                     NaN                 UNRELIABLE EXCHANGE RATES
#
#     Cheapest 1GB for 30 days (USD) Most expensive 1GB (USD)  \
# 237                            NaN                      NaN
# 238                            NaN                      NaN
# 239                            NaN                      NaN
# 240                            NaN                      NaN
# 241                            NaN                      NaN
#
#     Average price of 1GB (USD  at the start of 2021)  \
# 237                                              NaN
# 238                                              NaN
# 239                                              NaN
# 240                                              NaN
# 241                                              NaN
#
#     Average price of 1GB (USD – at start of 2020)
# 237                                           NaN
# 238                                           NaN
# 239                                           NaN
# 240                                           NaN
# 241                                           NaN

# %% [markdown]
# Checking  null values in all columns of Dataset

# %%
data.isnull().sum()
# Out:
# Country code                                         1
# Name                                                 0
# Continental region                                   0
# NO. OF Internet Plans                               12
# Average price of 1GB (USD)                           0
# Cheapest 1GB for 30 days (USD)                      12
# Most expensive 1GB (USD)                            12
# Average price of 1GB (USD  at the start of 2021)    12
# Average price of 1GB (USD – at start of 2020)       12
# dtype: int64

# %% [markdown]
# Number of row and columns in Dataset

# %%
data.shape
# Out:
# (242, 9)

# %% [markdown]
# Handling with missing Values

# %%
data.tail(13)
# Out:
#     Country code                            Name  Continental region  \
# 229           GQ               Equatorial Guinea  SUB-SAHARAN AFRICA
# 230           CW                Christmas Island           CARIBBEAN
# 231           ER                         Eritrea     NORTHERN AFRICA
# 232           KP                     North Korea           CARIBBEAN
# 233           MH                Marshall Islands             OCEANIA
# 234           PM         St. Pierre and Miquelon           CARIBBEAN
# 235           SS                     South Sudan  SUB-SAHARAN AFRICA
# 236           TT                          Tuvalu             OCEANIA
# 237           VA         Vatican City (Holy See)              Europe
# 238           VE                       Venezuela       SOUTH AMERICA
# 239           WF               Wallis and Futuna             OCEANIA
# 240           CD  Congo (Democratic Republic of)  SUB-SAHARAN AFRICA
# 241           ZW                        Zimbabwe  SUB-SAHARAN AFRICA
#
#      NO. OF Internet Plans                 Average price of 1GB (USD)  \
# 229                     4.0                                    $49.67
# 230                     NaN                              NO PROVIDERS
# 231                     NaN                              NO PROVIDERS
# 232                     NaN                              NO PROVIDERS
# 233                     NaN                              NO PROVIDERS
# 234                     NaN                              NO PROVIDERS
# 235                     NaN                              NO PROVIDERS
# 236                     NaN                              NO PROVIDERS
# 237                     NaN                              NO PROVIDERS
# 238                     NaN                            HYPERINFLATION
# 239                     NaN                              NO PROVIDERS
# 240                     NaN  Prices listed in non-convertible 'units'
# 241                     NaN                 UNRELIABLE EXCHANGE RATES
#
#     Cheapest 1GB for 30 days (USD) Most expensive 1GB (USD)  \
# 229                         $45.16                   $63.22
# 230                            NaN                      NaN
# 231                            NaN                      NaN
# 232                            NaN                      NaN
# 233                            NaN                      NaN
# 234                            NaN                      NaN
# 235                            NaN                      NaN
# 236                            NaN                      NaN
# 237                            NaN                      NaN
# 238                            NaN                      NaN
# 239                            NaN                      NaN
# 240                            NaN                      NaN
# 241                            NaN                      NaN
#
#     Average price of 1GB (USD  at the start of 2021)  \
# 229                                           $12.78
# 230                                              NaN
# 231                                              NaN
# 232                                              NaN
# 233                                              NaN
# 234                                              NaN
# 235                                              NaN
# 236                                              NaN
# 237                                              NaN
# 238                                              NaN
# 239                                              NaN
# 240                                              NaN
# 241                                              NaN
#
#     Average price of 1GB (USD – at start of 2020)
# 229                                        $47.39
# 230                                           NaN
# 231                                           NaN
# 232                                           NaN
# 233                                           NaN
# 234                                           NaN
# 235                                           NaN
# 236                                           NaN
# 237                                           NaN
# 238                                           NaN
# 239                                           NaN
# 240                                           NaN
# 241                                           NaN

# %% [markdown]
# We see that all missing values are at the bottom of dataset. And missing values are very less as compared to size of dataset we can simply drop them

# %%
data=data.dropna()

# %% [markdown]
# Number of rows and columns without Missing values

# %%
data.shape
# Out:
# (229, 9)

# %%
data.isnull().sum()
# Out:
# Country code                                        0
# Name                                                0
# Continental region                                  0
# NO. OF Internet Plans                               0
# Average price of 1GB (USD)                          0
# Cheapest 1GB for 30 days (USD)                      0
# Most expensive 1GB (USD)                            0
# Average price of 1GB (USD  at the start of 2021)    0
# Average price of 1GB (USD – at start of 2020)       0
# dtype: int64

# %% [markdown]
# Unique values in catagorical columns of Dataset

# %%
l=['Country code', 'Name', 'Continental region']
for i in l:
    print(f'{i}\t {data[i].unique()}')
# Out:
# Country code	 ['IL' 'KG' 'FJ' 'IT' 'SD' 'RU' 'MD' 'BD' 'LK' 'CL' 'FR' 'ID' 'BY' 'SM'
#  'VN' 'DZ' 'CN' 'WS' 'PK' 'KZ' 'UZ' 'SO' 'MN' 'NP' 'TR' 'PL' 'GH' 'IN'
#  'AU' 'LY' 'UA' 'TZ' 'MU' 'RE' 'AM' 'MM' 'DK' 'KW' 'YT' 'KH' 'BT' 'HT'
#  'NG' 'EH' 'MA' 'MY' 'GP' 'CM' 'BR' 'SN' 'NI' 'MK' 'FI' 'AF' 'EG' 'EC'
#  'TH' 'MC' 'TN' 'SG' 'DJ' 'ZM' 'IQ' 'PE' 'AT' 'RO' 'IS' 'ES' 'RW' 'TO'
#  'NE' 'RS' 'JE' 'SV' 'LT' 'EE' 'JO' 'GB' 'IE' 'SE' 'GG' 'SA' 'UY' 'DO'
#  'IR' 'UG' 'HN' 'GF' 'AO' 'PW' 'TL' 'HU' 'PS' 'ET' 'SI' 'DM' 'PH' 'GE'
#  'IM' 'AZ' 'TT' 'MO' 'GT' 'SR' 'GN' 'AS' 'VI' 'MT' 'BI' 'BH' 'OM' 'ME'
#  'GU' 'MP' 'BO' 'BN' 'SZ' 'KE' 'PG' 'BG' 'HK' 'HR' 'CR' 'BL' 'AR' 'BA'
#  'VC' 'GD' 'PY' 'CI' 'LR' 'TJ' 'LC' 'FO' 'LS' 'ZA' 'JM' 'AX' 'GI' 'MZ'
#  'AL' 'CO' 'CG' 'BZ' 'LU' 'LI' 'NL' 'LA' 'QA' 'KM' 'MV' 'SL' 'ML' 'US'
#  'DE' 'JP' 'MF' 'MQ' 'LV' 'CK' 'SK' 'BJ' 'MX' 'KN' 'PT' 'AI' 'BW' 'GL'
#  'PR' 'MS' 'SX' 'PF' 'GW' 'AG' 'AW' 'PA' 'BF' 'SJ' 'TG' 'KR' 'CV' 'LB'
#  'GA' 'MG' 'CH' 'GY' 'BE' 'MR' 'TW' 'CA' 'NO' 'GM' 'BS' 'VU' 'TV' 'CW'
#  'NC' 'BB' 'NZ' 'SY' 'NU' 'AD' 'CU' 'IO' 'AE' 'NR' 'SB' 'FM' 'TC' 'CZ'
#  'GR' 'SC' 'CY' 'CF' 'VG' 'KI' 'BQ' 'KY' 'CC' 'YE' 'BM' 'TK' 'TM' 'TD'
#  'MW' 'ST' 'SH' 'FK' 'GQ']
# Name	 ['Israel' 'Kyrgyzstan' 'Fiji' 'Italy' 'Sudan' 'Russian Federation'
#  'Moldova' 'Bangladesh' 'Sri Lanka' 'Chile' 'France' 'Indonesia' 'Belarus'
#  'San Marino' 'Vietnam' 'Algeria' 'China' 'Samoa' 'Pakistan' 'Kazakhstan'
#  'Uzbekistan' 'Somalia' 'Mongolia' 'Nepal' 'Turkey' 'Poland' 'Ghana'
#  'India' 'Australia' 'Libya' 'Ukraine' 'Tanzania' 'Mauritius' 'Réunion'
#  'Armenia' 'Myanmar' 'Denmark' 'Kuwait' 'Mayotte' 'Cambodia' 'Bhutan'
#  'Haiti' 'Nigeria' 'Western Sahara' 'Morocco' 'Malaysia' 'Guadeloupe'
#  'Cameroon' 'Brazil' 'Senegal' 'Nicaragua' 'Macedonia' 'Finland'
#  'Afghanistan' 'Egypt' 'Ecuador' 'Thailand' 'Monaco' 'Tunisia' 'Singapore'
#  'Djibouti' 'Zambia' 'Iraq' 'Peru' 'Austria' 'Romania' 'Iceland' 'Spain'
#  'Rwanda' 'Tonga' 'Niger' 'Serbia' 'Jersey' 'El Salvador' 'Lithuania'
#  'Estonia' 'Jordan' 'United Kingdom' 'Ireland' 'Sweden' 'Guernsey'
#  'Saudi Arabia' 'Uruguay' 'Dominican Republic' 'Iran' 'Uganda' 'Honduras'
#  'French Guiana' 'Angola' 'Palau' 'Timor-Leste' 'Hungary'
#  'Palestine, State of' 'Ethiopia' 'Slovenia' 'Dominica' 'Philippines'
#  'Georgia' 'Isle of Man' 'Azerbaijan' 'Trinidad and Tobago' 'Macau'
#  'Guatemala' 'Suriname' 'Guinea' 'American Samoa' 'Virgin Islands (U.S.)'
#  'Malta' 'Burundi' 'Bahrain' 'Oman' 'Montenegro' 'Guam'
#  'Northern Mariana Islands' 'Bolivia' 'Brunei Darussalam' 'Eswatini'
#  'Kenya' 'Papua New Guinea' 'Bulgaria' 'Hong Kong' 'Croatia' 'Costa Rica'
#  'Saint Barthélemy (St. Barts)' 'Argentina' 'Bosnia and Herzegovina'
#  'Saint Vincent and the Grenadines' 'Grenada' 'Paraguay' "Côte d'Ivoire"
#  'Liberia' 'Tajikistan' 'Saint Lucia' 'Faroe Islands' 'Lesotho'
#  'South Africa' 'Jamaica' 'Åland Islands' 'Gibraltar' 'Mozambique'
#  'Albania' 'Colombia' 'Congo' 'Belize' 'Luxembourg' 'Liechtenstein'
#  'The Netherlands' "Lao People's Democratic Republic" 'Qatar' 'Comoros'
#  'Maldives' 'Sierra Leone' 'Mali' 'United States' 'Germany' 'Japan'
#  'Saint-Martin (France)' 'Martinique' 'Latvia' 'Cook Islands' 'Slovakia'
#  'Benin' 'Mexico' 'Saint Kitts and Nevis' 'Portugal' 'Anguilla' 'Botswana'
#  'Greenland' 'Puerto Rico' 'Montserrat' 'Sint Maarten' 'French Polynesia'
#  'Guinea-Bissau' 'Antigua and Barbuda' 'Aruba' 'Panama' 'Burkina Faso'
#  'Svalbard and Jan Mayen' 'Togo' 'South Korea' 'Cape Verde' 'Lebanon'
#  'Gabon' 'Madagascar' 'Switzerland' 'Guyana' 'Belgium' 'Mauritania'
#  'Taiwan' 'Canada' 'Norway' 'Gambia' 'Bahamas' 'Vanuatu' 'Tuvalu'
#  'Curaçao' 'New Caledonia' 'Barbados' 'New Zealand' 'Syria' 'Niue'
#  'Andorra' 'Cuba' 'British Indian Ocean Territory' 'United Arab Emirates'
#  'Nauru' 'Solomon Islands' 'Micronesia (Federated States of)'
#  'Turks and Caicos Islands' 'Czech Republic' 'Greece' 'Seychelles'
#  'Cyprus' 'Central African Republic' 'Virgin Islands (British)' 'Kiribati'
#  'Caribbean Netherlands' 'Cayman Islands' 'Cocos (Keeling) Islands'
#  'Yemen' 'Bermuda' 'Tokelau' 'Turkmenistan' 'Chad' 'Malawi'
#  'São Tomé and Príncipe' 'Saint Helena' 'Falkland Islands'
#  'Equatorial Guinea']
# Continental region	 ['NEAR EAST' 'CIS (FORMER USSR)' 'OCEANIA' 'WESTERN EUROPE'
#  'SUB-SAHARAN AFRICA' 'EASTERN EUROPE' 'ASIA (EX. NEAR EAST)'
#  'SOUTH AMERICA' 'NORTHERN AFRICA' 'CARIBBEAN' 'CENTRAL AMERICA' 'BALTICS'
#  'NORTHERN AMERICA']

# %% [markdown]
# Cleaning The Dataset: In order to perform numerical calculations on the Dataset we have to change the datatypes of numerical columns from "object" to "int".

# %%
#printing columns names
data.columns
# Out:
# Index(['Country code', 'Name', 'Continental region', 'NO. OF Internet Plans ',
#        'Average price of 1GB (USD)', 'Cheapest 1GB for 30 days (USD)',
#        'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)'],
#       dtype='object')

# %%
data['Average price of 1GB (USD  at the start of 2021)']=data['Average price of 1GB (USD  at the start of 2021)'].str.replace('NO PACKAGES','0')
data['Average price of 1GB (USD – at start of 2020)']=data['Average price of 1GB (USD – at start of 2020)'].str.replace('NO PACKAGES','0')

# %%
#changing Object data types of numerical columns to int
ls=  ['Average price of 1GB (USD)', 'Cheapest 1GB for 30 days (USD)','Most expensive 1GB (USD)','Average price of 1GB (USD  at the start of 2021)',
       'Average price of 1GB (USD – at start of 2020)']
for i in ls:
    data[i]=data[i].str.replace('$','').astype('float')
# Out:
# c:\Program Files\Python37\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 0 to 229
# Data columns (total 9 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Country code                                      229 non-null    object
#  1   Name                                              229 non-null    object
#  2   Continental region                                229 non-null    object
#  3   NO. OF Internet Plans                             229 non-null    float64
#  4   Average price of 1GB (USD)                        229 non-null    float64
#  5   Cheapest 1GB for 30 days (USD)                    229 non-null    float64
#  6   Most expensive 1GB (USD)                          229 non-null    float64
#  7   Average price of 1GB (USD  at the start of 2021)  229 non-null    float64
#  8   Average price of 1GB (USD – at start of 2020)     229 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 17.9+ KB

# %%
data.head()
#we have converted datatypes of numerical columns and also remove $ sign from price
# Out:
#   Country code        Name  Continental region  NO. OF Internet Plans   \
# 0           IL      Israel           NEAR EAST                    27.0
# 1           KG  Kyrgyzstan   CIS (FORMER USSR)                    20.0
# 2           FJ        Fiji             OCEANIA                    18.0
# 3           IT       Italy      WESTERN EUROPE                    29.0
# 4           SD       Sudan  SUB-SAHARAN AFRICA                    33.0
#
#    Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0                        0.05                            0.02
# 1                        0.15                            0.10
# 2                        0.19                            0.05
# 3                        0.27                            0.09
# 4                        0.27                            0.03
#
#    Most expensive 1GB (USD)  Average price of 1GB (USD  at the start of 2021)  \
# 0                     20.95                                              0.11
# 1                      7.08                                              0.21
# 2                      0.85                                              0.59
# 3                      3.54                                              0.43
# 4                      0.92                                              0.63
#
#    Average price of 1GB (USD – at start of 2020)
# 0                                           0.90
# 1                                           0.27
# 2                                           3.57
# 3                                           1.73
# 4                                           0.68

# %% [markdown]
# Data Visualization

# %%
#top 10 Countries based on Highest Average price of 1GB (USD)
top_10_having_Highest_Average_price_of_1GB=data.sort_values(by='Average price of 1GB (USD)',ascending=False).head(10)
top_10_having_Highest_Average_price_of_1GB[['Name','Average price of 1GB (USD)']]
# Out:
#                       Name  Average price of 1GB (USD)
# 229      Equatorial Guinea                       49.67
# 228       Falkland Islands                       44.56
# 227           Saint Helena                       39.87
# 226  São Tomé and Príncipe                       30.97
# 225                 Malawi                       25.46
# 224                   Chad                       23.33
# 222           Turkmenistan                       21.41
# 221                Tokelau                       20.48
# 220                Bermuda                       19.80
# 219                  Yemen                       15.98

# %%
#bar Graph of top 10 Countries based on Highest Average price of 1GB (USD)
labels=['Equatorial Guinea', 'Falkland Islands', 'Saint Helena',
       'São Tomé and Príncipe', 'Malawi', 'Chad', 'Turkmenistan',
       'Tokelau', 'Bermuda', 'Yemen']
plt.figure(figsize=(10,7))
ax=sns.barplot(top_10_having_Highest_Average_price_of_1GB['Name'],top_10_having_Highest_Average_price_of_1GB['Average price of 1GB (USD)'])
ax.set_xticklabels(labels,rotation=45)
plt.show()
# Out:
# c:\Program Files\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Pie chart of top 10 Countries based on Highest Average price of 1GB (USD)
plt.figure(figsize=(7,7))
plt.pie(top_10_having_Highest_Average_price_of_1GB['Average price of 1GB (USD)'],labels=top_10_having_Highest_Average_price_of_1GB['Name'],autopct='%.0f%%')
plt.show()
#Pie chart shows the camparison between  Average price of internet between top 10 Countries based on Highest Average price of 1GB (USD)

# %%
#top 10 Countries based on Lowest Average price of 1GB (USD)
top_10_having_Lowest_Average_price_of_1GB=data.sort_values(by='Average price of 1GB (USD)',ascending=True).head(10)
top_10_having_Lowest_Average_price_of_1GB[['Name','Average price of 1GB (USD)']]
# Out:
#                  Name  Average price of 1GB (USD)
# 0              Israel                        0.05
# 1          Kyrgyzstan                        0.15
# 2                Fiji                        0.19
# 3               Italy                        0.27
# 4               Sudan                        0.27
# 5  Russian Federation                        0.29
# 6             Moldova                        0.32
# 7          Bangladesh                        0.34
# 8           Sri Lanka                        0.38
# 9               Chile                        0.39

# %%
#bar chart of top 10 Countries based on Lowest Average price of 1GB (USD)
plt.figure(figsize=(10,7))
labels=['Israel', 'Kyrgyzstan', 'Fiji', 'Italy', 'Sudan',
       'Russian Federation', 'Moldova', 'Bangladesh', 'Sri Lanka',
       'Chile']
ax=sns.barplot(top_10_having_Lowest_Average_price_of_1GB['Name'],top_10_having_Lowest_Average_price_of_1GB['Average price of 1GB (USD)'])
ax.set_xticklabels(labels,rotation=45)
plt.show()
# Out:
# c:\Program Files\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Pie chart of top 10 Countries based on Lowest Average price of 1GB (USD)
plt.figure(figsize=(7,7))
plt.pie(top_10_having_Highest_Average_price_of_1GB['Average price of 1GB (USD)'],labels=top_10_having_Highest_Average_price_of_1GB['Name'],autopct='%.0f%%')
plt.show()
#Pie chart shows the camparison between price of internet between top 10 Countries based on Lowest Average price of 1GB (USD)

# %%
#Top 10 Countries based on highest Average price of 1GB (USD) in 2020
top_10_having_Highest_Average_price_of_1GB2020=data.sort_values(by='Average price of 1GB (USD – at start of 2020)',ascending=False).head(10)
top_10_having_Highest_Average_price_of_1GB2020[['Name','Average price of 1GB (USD – at start of 2020)']]
# Out:
#                   Name  Average price of 1GB (USD – at start of 2020)
# 50           Nicaragua                                          65.83
# 228   Falkland Islands                                          55.47
# 229  Equatorial Guinea                                          47.39
# 60            Djibouti                                          37.92
# 220            Bermuda                                          37.74
# 209     Czech Republic                                          32.71
# 17               Samoa                                          30.09
# 221            Tokelau                                          29.96
# 205              Nauru                                          28.13
# 217     Cayman Islands                                          26.79

# %%
#Top 10 Countries based on highest Average price of 1GB (USD) in 2020
top_10_having_Highest_Average_price_of_1GB2021=data.sort_values(by='Average price of 1GB (USD  at the start of 2021)',ascending=False).head(10)
top_10_having_Highest_Average_price_of_1GB2021[['Name','Average price of 1GB (USD  at the start of 2021)']]
# Out:
#                       Name  Average price of 1GB (USD  at the start of 2021)
# 227           Saint Helena                                             52.50
# 228       Falkland Islands                                             40.41
# 205                  Nauru                                             30.47
# 220                Bermuda                                             28.75
# 226  São Tomé and Príncipe                                             28.26
# 225                 Malawi                                             27.41
# 161                  Benin                                             27.22
# 224                   Chad                                             23.33
# 217         Cayman Islands                                             23.05
# 221                Tokelau                                             17.75

# %%
#Top 10 Countries based on highest Average price of 1GB (USD) in 2020
top_10_having_Highest_Average_price_of_1GB2020=data.sort_values(by='Average price of 1GB (USD – at start of 2020)',ascending=False).head(10)
top_10_having_Highest_Average_price_of_1GB2020[['Name','Average price of 1GB (USD – at start of 2020)']]
# Out:
#                   Name  Average price of 1GB (USD – at start of 2020)
# 50           Nicaragua                                          65.83
# 228   Falkland Islands                                          55.47
# 229  Equatorial Guinea                                          47.39
# 60            Djibouti                                          37.92
# 220            Bermuda                                          37.74
# 209     Czech Republic                                          32.71
# 17               Samoa                                          30.09
# 221            Tokelau                                          29.96
# 205              Nauru                                          28.13
# 217     Cayman Islands                                          26.79

# %%
fig,ax=plt.subplots(3,1)
fig.set_size_inches(15,10)
# fig.set_dpi(100)
ax[0].bar(top_10_having_Highest_Average_price_of_1GB['Name'],top_10_having_Highest_Average_price_of_1GB['Average price of 1GB (USD)'])
ax[0].set_title('Top 10 Countries based on Highest Average price of 1GB (USD)')
ax[1].bar(top_10_having_Highest_Average_price_of_1GB2021['Name'],top_10_having_Highest_Average_price_of_1GB2021['Average price of 1GB (USD  at the start of 2021)'])
ax[1].set_title('Top 10 Countries based on Highest Average price of 1GB (USD) at start of 2021')
ax[2].bar(top_10_having_Highest_Average_price_of_1GB2020['Name'],top_10_having_Highest_Average_price_of_1GB2020['Average price of 1GB (USD – at start of 2020)'])
ax[2].set_title('Top 10 Countries based on Highest Average price of 1GB (USD) at start of 2020')
plt.tight_layout()

# %%
sns.histplot(data['Average price of 1GB (USD)'],bins=15)
# Out:
# <AxesSubplot:xlabel='Average price of 1GB (USD)', ylabel='Count'>

# %% [markdown]
# histagram is showing that most of countries have 'Average price of 1GB ' lies between 0$ to 4$, And ther are very less countries having 'Average price of 1GB'
# more than 10$

# %%
sns.histplot(data['Average price of 1GB (USD  at the start of 2021)'],bins=15)
# Out:
# <AxesSubplot:xlabel='Average price of 1GB (USD  at the start of 2021)', ylabel='Count'>

# %%
sns.histplot(data['Average price of 1GB (USD – at start of 2020)'],bins=15)
# Out:
# <AxesSubplot:xlabel='Average price of 1GB (USD – at start of 2020)', ylabel='Count'>

# %%
data[['Average price of 1GB (USD)','Average price of 1GB (USD  at the start of 2021)',
       'Average price of 1GB (USD – at start of 2020)']].plot.hist(subplots=True, layout=(1,3), figsize=(10, 5), bins=15)
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %% [markdown]
# If we compare the histograms 'Average price of 1GB (USD – at start of 2020)' vs 'Average price of 1GB (USD  at the start of 2021)' vs present average price. We can see than most of countries internet prices are decreased from 2020 to 2022

# %%
#we can cross validate our above conclusion
def divisionToGroups(t):
    t=t.tolist()
    for i in range(len(t)):
        if t[i]<=5:
            t[i]=1
        elif t[i]>5 and t[i]<=10:
            t[i]=2
        elif t[i]>10 and t[i]<=15:
            t[i]=3
        elif t[i]>15 and t[i]<=20:
            t[i]=4
        else:
            t[i]=5
    return pd.Series(t)

# %%
data.columns
# Out:
# Index(['Country code', 'Name', 'Continental region', 'NO. OF Internet Plans ',
#        'Average price of 1GB (USD)', 'Cheapest 1GB for 30 days (USD)',
#        'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)'],
#       dtype='object')

# %%
d=data.copy()
d['Average price of 1GB (USD)']=divisionToGroups(data['Average price of 1GB (USD)'])
d['Average price of 1GB (USD  at the start of 2021)']=divisionToGroups(data['Average price of 1GB (USD  at the start of 2021)'])
d['Average price of 1GB (USD – at start of 2020)']=divisionToGroups(data['Average price of 1GB (USD – at start of 2020)'])
l1=d['Average price of 1GB (USD – at start of 2020)'].value_counts()
l1=l1.tolist()
l2=d['Average price of 1GB (USD  at the start of 2021)'].value_counts()
l2=l2.tolist()
l3=d['Average price of 1GB (USD)'].value_counts()
l3=l3.tolist()

# %%
df=pd.DataFrame({'Price ($) Range of 1GB  ':['0 to 5','6 to 10','11 to 15','16 to 20 ','Greater than 20'],
'Count of Contries 2020': l1,
'Count of Contries 2021': l2,
'Count of Contries 2022': l3})

# %%
df
# Out:
#   Price ($) Range of 1GB    Count of Contries 2020  Count of Contries 2021  \
# 0                   0 to 5                     113                     167
# 1                  6 to 10                      55                      33
# 2                 11 to 15                      32                      16
# 3                16 to 20                       16                       8
# 4          Greater than 20                      12                       4
#
#    Count of Contries 2022
# 0                     183
# 1                      33
# 2                       7
# 3                       3
# 4                       2

# %%
plt.figure(figsize=(10,45))
sns.barplot(data['Average price of 1GB (USD)'],data['Name'])
# Out:
# c:\Program Files\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Average price of 1GB (USD)', ylabel='Name'>

# %% [markdown]
# Influence of number of Internet plans on Price of Internet

# %%
data.columns
# Out:
# Index(['Country code', 'Name', 'Continental region', 'NO. OF Internet Plans ',
#        'Average price of 1GB (USD)', 'Cheapest 1GB for 30 days (USD)',
#        'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)'],
#       dtype='object')

# %%
sns.lineplot(data['NO. OF Internet Plans '],data['Average price of 1GB (USD)'])
# Out:
# c:\Program Files\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='NO. OF Internet Plans ', ylabel='Average price of 1GB (USD)'>

# %%
sns.heatmap(data[['NO. OF Internet Plans ','Average price of 1GB (USD)']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Correlantion and lineplot shows that if we increase the number of internet plans the Average price of internet will decrease

# %%
ls=['NEAR EAST', 'CIS (FORMER USSR)', 'OCEANIA', 'WESTERN EUROPE',
       'SUB-SAHARAN AFRICA', 'EASTERN EUROPE', 'ASIA (EX. NEAR EAST)',
       'SOUTH AMERICA', 'NORTHERN AFRICA', 'CARIBBEAN', 'CENTRAL AMERICA',
       'BALTICS', 'NORTHERN AMERICA']
averages=[]
for i in ls:
    t=data[data['Continental region']==i]
    averages.append(t['Average price of 1GB (USD)'].median())

# %%
#camparison between the internet prices in different 'Continental region'
plt.figure(figsize=(10,10))
plt.pie(averages,labels=ls,autopct='%.0f%%')
plt.show()

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data['Continental region'].value_counts()
# Out:
# SUB-SAHARAN AFRICA      46
# WESTERN EUROPE          30
# ASIA (EX. NEAR EAST)    28
# CARIBBEAN               28
# OCEANIA                 22
# NEAR EAST               15
# EASTERN EUROPE          14
# SOUTH AMERICA           13
# CIS (FORMER USSR)       11
# CENTRAL AMERICA          8
# NORTHERN AFRICA          7
# NORTHERN AMERICA         4
# BALTICS                  3
# Name: Continental region, dtype: int64

# %%
plt.figure(figsize=(20,7))
ax=sns.barplot(data['Continental region'],data['Average price of 1GB (USD)'])
ax.set_xticklabels(['NEAR EAST', 'CIS (FORMER USSR)', 'OCEANIA', 'WESTERN EUROPE',
       'SUB-SAHARAN AFRICA', 'EASTERN EUROPE', 'ASIA (EX. NEAR EAST)',
       'SOUTH AMERICA', 'NORTHERN AFRICA', 'CARIBBEAN', 'CENTRAL AMERICA',
       'BALTICS', 'NORTHERN AMERICA'],rotation=45)
plt.show()
# Out:
# c:\Program Files\Python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.columns
# Out:
# Index(['Country code', 'Name', 'Continental region', 'NO. OF Internet Plans ',
#        'Average price of 1GB (USD)', 'Cheapest 1GB for 30 days (USD)',
#        'Most expensive 1GB (USD)',
#        'Average price of 1GB (USD  at the start of 2021)',
#        'Average price of 1GB (USD – at start of 2020)'],
#       dtype='object')

# %%
data[['Cheapest 1GB for 30 days (USD)',
       'Most expensive 1GB (USD)',]].plot.hist(subplots=True, layout=(1,2), figsize=(7, 7), bins=20)
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)
